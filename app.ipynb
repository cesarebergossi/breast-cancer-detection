# %% [markdown]
# # Web Interface for Classification and Segmentation
#
# How to use:
# - Run the following cell (it should open a webpage in your browser, if it doesn't automatically open, copy and paste the provided URL)
# - Select an image and see the result! (one test image is in the root folder of the project)
# - Once you are done, stop the cell

# %% [markdown]
# **Make sure Streamlit is installed**

# %%
# !pip install streamlit

# %%
# !streamlit run app.py --server.enableXsrfProtection false
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://10.18.0.158:8501
#   External URL: http://40.68.157.149:8501
#
# ^C
#   Stopping...
